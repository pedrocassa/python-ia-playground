# %%
-Goal-
Given a text document that is potentially relevant to this activity and a list of entity types, identify all entities of those types from the text and all relationships among the identified entities.

-Steps-
1. Identify all entities. For each identified entity, extract the following information:
- entity_name: Name of the entity, capitalized
- entity_type: One of the following types: [fundo de investimento, classe de cotas, administrador fiduciário, gestor, consultoria especializada, direitos creditórios, imóvel rural, créditos de carbono, CBIO, política de investimento, regulamento, assembleia de cotistas, laudo de avaliação, representante dos cotistas, distribuição de cotas, informe mensal, lâmina de informações básicas, informe anual, prestação de serviços, taxa de administração, taxa de performance, taxa de custódia, distribuição de rendimentos, ativos financeiros, títulos de securitização, participação societária, oferta pública, sistema eletrônico da CVM, mercado organizado, entidade registradora, depositário central, avaliação de imóveis, direitos de voto]
- entity_description: Comprehensive description of the entity's attributes and activities
Format each entity as ("entity"{{tuple_delimiter}}<entity_name>{{tuple_delimiter}}<entity_type>{{tuple_delimiter}}<entity_description>)

2. From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are *clearly related* to each other.
For each pair of related entities, extract the following information:
- source_entity: name of the source entity, as identified in step 1
- target_entity: name of the target entity, as identified in step 1
- relationship_description: explanation as to why you think the source entity and the target entity are related to each other
- relationship_strength: an integer score between 1 to 10, indicating strength of the relationship between the source entity and target entity
Format each relationship as ("relationship"{{tuple_delimiter}}<source_entity>{{tuple_delimiter}}<target_entity>{{tuple_delimiter}}<relationship_description>{{tuple_delimiter}}<relationship_strength>)

3. Return output in The primary language of the provided text is "Portuguese." as a single list of all the entities and relationships identified in steps 1 and 2. Use **{{record_delimiter}}** as the list delimiter.

4. If you have to translate into The primary language of the provided text is "Portuguese.", just translate the descriptions, nothing else!

5. When finished, output {{completion_delimiter}}.

-Examples-
entity_types: [fundo de investimento, classe de cotas, administrador fiduciário, gestor, consultoria especializada, direitos creditórios, imóvel rural, créditos de carbono, CBIO, política de investimento, regulamento, assembleia de cotistas, laudo de avaliação, representante dos cotistas, distribuição de cotas, informe mensal, lâmina de informações básicas, informe anual, prestação de serviços, taxa de administração, taxa de performance, taxa de custódia, distribuição de rendimentos, ativos financeiros, títulos de securitização, participação societária, oferta pública, sistema eletrônico da CVM, mercado organizado, entidade registradora, depositário central, avaliação de imóveis, direitos de voto]

text:
A Resolução CVM nº 214, de 30 de setembro de 2024, acrescenta à Resolução CVM nº 175 regras específicas aplicáveis aos FIAGRO – Fundos de Investimento nas Cadeias Produtivas do Agronegócio. O regulamento do fundo deve especificar a política de investimento, incluindo limites por emissor e tipo de ativo, e descrever como será realizado o controle sobre os créditos de carbono. É obrigatória a elaboração de laudo de avaliação para a integralização em imóvel rural. Os representantes dos cotistas têm a função de fiscalizar os atos do gestor e do administrador fiduciário e devem elaborar relatório anual. O administrador também é responsável por disponibilizar o informe mensal e o informe anual via sistema eletrônico da CVM.

output:
("entity"{{tuple_delimiter}}FIAGRO{{tuple_delimiter}}fundo de investimento{{tuple_delimiter}}FIAGRO é o Fundo de Investimento nas Cadeias Produtivas do Agronegócio, voltado para aplicação de recursos em ativos relacionados ao setor agropecuário)
{{record_delimiter}}
("entity"{{tuple_delimiter}}POLÍTICA DE INVESTIMENTO{{tuple_delimiter}}política de investimento{{tuple_delimiter}}A política de investimento define os ativos elegíveis para o portfólio do fundo, os limites de exposição por ativo e emissor, e diretrizes como o controle de créditos de carbono)
{{record_delimiter}}
("entity"{{tuple_delimiter}}REGULAMENTO{{tuple_delimiter}}regulamento{{tuple_delimiter}}O regulamento do fundo deve detalhar as regras operacionais, critérios de investimento, obrigações do administrador e disposições sobre classes de cotas)
{{record_delimiter}}
("entity"{{tuple_delimiter}}CRÉDITOS DE CARBONO{{tuple_delimiter}}créditos de carbono{{tuple_delimiter}}Créditos de carbono no agronegócio representam títulos ligados à redução ou remoção de gases do efeito estufa, sendo ativos passíveis de investimento por FIAGROs)
{{record_delimiter}}
("entity"{{tuple_delimiter}}IMÓVEL RURAL{{tuple_delimiter}}imóvel rural{{tuple_delimiter}}Imóvel rural é uma propriedade que possui CCIR e é utilizada em atividades agropecuárias, podendo ser incluída no portfólio do FIAGRO mediante avaliação prévia)
{{record_delimiter}}
("entity"{{tuple_delimiter}}LAUDO DE AVALIAÇÃO{{tuple_delimiter}}laudo de avaliação{{tuple_delimiter}}O laudo de avaliação é o documento técnico exigido para avaliar o valor de ativos como imóveis rurais antes de sua integralização no fundo)
{{record_delimiter}}
("entity"{{tuple_delimiter}}REPRESENTANTE DOS COTISTAS{{tuple_delimiter}}representante dos cotistas{{tuple_delimiter}}O representante dos cotistas é eleito em assembleia para fiscalizar a gestão do fundo e deve produzir relatórios periódicos e pareceres sobre as demonstrações contábeis)
{{record_delimiter}}
("entity"{{tuple_delimiter}}ADMINISTRADOR FIDUCIÁRIO{{tuple_delimiter}}administrador fiduciário{{tuple_delimiter}}O administrador fiduciário é responsável pela administração do fundo, incluindo a disponibilização dos informes obrigatórios e a supervisão da custódia de ativos)
{{record_delimiter}}
("entity"{{tuple_delimiter}}INFORME MENSAL{{tuple_delimiter}}informe mensal{{tuple_delimiter}}O informe mensal é um documento obrigatório que contém dados sobre o desempenho, carteira e indicadores financeiros do FIAGRO, divulgado via sistema da CVM)
{{record_delimiter}}
("entity"{{tuple_delimiter}}INFORME ANUAL{{tuple_delimiter}}informe anual{{tuple_delimiter}}O informe anual consolida as informações do fundo ao fim do exercício social e deve ser disponibilizado eletronicamente aos cotistas e à CVM)
{{record_delimiter}}
("entity"{{tuple_delimiter}}SISTEMA ELETRÔNICO DA CVM{{tuple_delimiter}}sistema eletrônico da CVM{{tuple_delimiter}}Plataforma digital da Comissão de Valores Mobiliários utilizada para envio e divulgação de informações regulatórias dos fundos de investimento)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}FIAGRO{{tuple_delimiter}}POLÍTICA DE INVESTIMENTO{{tuple_delimiter}}A política de investimento é parte fundamental da estrutura do FIAGRO, definindo como os recursos serão aplicados{{tuple_delimiter}}9)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}REGULAMENTO{{tuple_delimiter}}POLÍTICA DE INVESTIMENTO{{tuple_delimiter}}O regulamento deve explicitar claramente a política de investimento, incluindo limites de aplicação e ativos permitidos{{tuple_delimiter}}8)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}CRÉDITOS DE CARBONO{{tuple_delimiter}}POLÍTICA DE INVESTIMENTO{{tuple_delimiter}}A política de investimento deve indicar como será feito o controle e certificação dos créditos de carbono adquiridos pelo fundo{{tuple_delimiter}}7)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}IMÓVEL RURAL{{tuple_delimiter}}LAUDO DE AVALIAÇÃO{{tuple_delimiter}}A aquisição de imóvel rural pelo fundo exige a elaboração de laudo de avaliação prévia{{tuple_delimiter}}9)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}REPRESENTANTE DOS COTISTAS{{tuple_delimiter}}ADMINISTRADOR FIDUCIÁRIO{{tuple_delimiter}}O representante dos cotistas fiscaliza os atos do administrador fiduciário para proteger os interesses dos cotistas{{tuple_delimiter}}8)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}ADMINISTRADOR FIDUCIÁRIO{{tuple_delimiter}}INFORME MENSAL{{tuple_delimiter}}O administrador fiduciário é responsável por publicar o informe mensal com dados atualizados do fundo{{tuple_delimiter}}9)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}ADMINISTRADOR FIDUCIÁRIO{{tuple_delimiter}}INFORME ANUAL{{tuple_delimiter}}O administrador fiduciário deve disponibilizar o informe anual no sistema eletrônico da CVM{{tuple_delimiter}}9)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}INFORME MENSAL{{tuple_delimiter}}SISTEMA ELETRÔNICO DA CVM{{tuple_delimiter}}O informe mensal é enviado e publicado através do sistema eletrônico da CVM para acesso público{{tuple_delimiter}}8)
{{record_delimiter}}
("relationship"{{tuple_delimiter}}INFORME ANUAL{{tuple_delimiter}}SISTEMA ELETRÔNICO DA CVM{{tuple_delimiter}}O informe anual deve ser divulgado eletronicamente por meio da plataforma da CVM{{tuple_delimiter}}8)
{{completion_delimiter}}


-Real Data-
######################
entity_types: [fundo de investimento, classe de cotas, administrador fiduciário, gestor, consultoria especializada, direitos creditórios, imóvel rural, créditos de carbono, CBIO, política de investimento, regulamento, assembleia de cotistas, laudo de avaliação, representante dos cotistas, distribuição de cotas, informe mensal, lâmina de informações básicas, informe anual, prestação de serviços, taxa de administração, taxa de performance, taxa de custódia, distribuição de rendimentos, ativos financeiros, títulos de securitização, participação societária, oferta pública, sistema eletrônico da CVM, mercado organizado, entidade registradora, depositário central, avaliação de imóveis, direitos de voto]
text: Conteúdo integral da RESOLUÇÃO CVM Nº 214, DE 30 DE SETEMBRO DE 2024
######################
output:

# %%
import networkx as nx

# 1. Lê o arquivo de entrada
with open('entrada-processada-res.txt', 'r', encoding='utf-8') as f:
    lines = f.readlines()

# 2. Cria o grafo direcionado
G = nx.DiGraph()

# 3. Processa cada linha
for line in lines:
    if line.startswith('("entity'):
        # Exemplo: ("entity"{{tuple_delimiter}}LARGE LANGUAGE MODELS{{tuple_delimiter}}large language model{{tuple_delimiter}}Large language models (LLMs) are advanced AI models designed...
        parts = line.split('{{tuple_delimiter}}')
        entity_name = parts[1].strip()
        entity_type = parts[2].strip()
        entity_desc = parts[3].split(')')[0].strip()  # até fechar o parênteses

        # Adiciona como nó com atributos
        G.add_node(entity_name, type=entity_type, description=entity_desc)

    elif line.startswith('("relationship'):
        # Exemplo: ("relationship"{{tuple_delimiter}}LARGE LANGUAGE MODELS{{tuple_delimiter}}DATASETS{{tuple_delimiter}}Large language models are trained using large datasets{{tuple_delimiter}}8
        parts = line.split('{{tuple_delimiter}}')
        src = parts[1].strip()
        tgt = parts[2].strip()
        relation_desc = parts[3].strip()

        # Adiciona como aresta com descrição
        G.add_edge(src, tgt, description=relation_desc)

print(f"Grafo criado com {G.number_of_nodes()} nós e {G.number_of_edges()} arestas.")

# (Opcional) 4. Exemplo: listar as relações
for u, v, data in G.edges(data=True):
    print(f"{u} -> {v} : {data['description']}")
# Out:
# Grafo criado com 33 nós e 9 arestas.
# FIAGRO -> CLASSE DE COTAS : Cada FIAGRO pode ter uma ou mais classes de cotas com políticas de investimento específicas e características próprias
# FIAGRO -> POLÍTICA DE INVESTIMENTO : A política de investimento define como o FIAGRO aplicará seus recursos, em quais ativos e com quais limites
# ADMINISTRADOR FIDUCIÁRIO -> INFORME MENSAL : O administrador fiduciário deve elaborar e divulgar o informe mensal com informações detalhadas do fundo
# ADMINISTRADOR FIDUCIÁRIO -> INFORME ANUAL : O administrador é responsável pela divulgação anual das demonstrações contábeis e relatório do fundo
# GESTOR -> POLÍTICA DE INVESTIMENTO : O gestor é o responsável pela execução da política de investimento conforme definida no regulamento
# CRÉDITOS DE CARBONO -> POLÍTICA DE INVESTIMENTO : A política deve especificar critérios para aquisição, titularidade e certificação dos créditos de carbono do agronegócio
# ...

# %%
from difflib import get_close_matches

def buscar_no_grafo(pergunta, top_k=3):
    # 1. Lista todos os nós
    todos_nos = list(G.nodes)
    
    # 2. Usa fuzzy match para encontrar nós mais similares à pergunta
    matches = get_close_matches(pergunta.upper(), todos_nos, n=top_k, cutoff=0.1)
    
    contexto = []
    for match in matches:
        node_data = G.nodes[match]
        contexto.append(f"Entidade: {match} ({node_data['type']})\nDescrição: {node_data['description']}")
        
        # 3. Pega relações de saída
        for _, target, edge_data in G.out_edges(match, data=True):
            contexto.append(f"Relacionamento: {match} -> {target}\nDescrição: {edge_data['description']}")
        
        # 4. Pega relações de entrada
        for source, _, edge_data in G.in_edges(match, data=True):
            contexto.append(f"Relacionamento: {source} -> {match}\nDescrição: {edge_data['description']}")
    
    return "\n\n".join(contexto)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# ✅ Detecta se há GPU (CUDA) disponível
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🔎 Usando dispositivo: {device}")

# ✅ Passo 2: Carregar TinyLlama (sem device_map)
print("🔄 Carregando modelo TinyLlama...")
model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name, torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
).to(device)
print("✅ Modelo TinyLlama carregado!")
# Out:
# 🔎 Usando dispositivo: cpu
# 🔄 Carregando modelo TinyLlama...
# ✅ Modelo TinyLlama carregado!

# %%
def responder_graphrag(pergunta_usuario):
    # 🔍 Passo 1: Buscar contexto no grafo
    contexto = buscar_no_grafo(pergunta_usuario)
    
    # 🧠 Passo 2: Montar prompt estilo RAG
    prompt = f"""
    Você é um assistente especializado na Resolução CVM nº 214/2024 sobre os FIAGRO – Fundos de Investimento nas Cadeias Produtivas do Agronegócio.
    
    Baseie-se **exclusivamente** no contexto a seguir para responder à pergunta de forma **clara e objetiva**. Não invente conteúdo. Se a resposta não estiver no contexto, diga: "A informação não está disponível no contexto."
    
    Contexto:
    {contexto}
    
    Pergunta:
    {pergunta_usuario}
    
    Resposta:
    """

    # Tokeniza
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    
    # Gera resposta
    outputs = model.generate(**inputs, max_new_tokens=300, temperature=0.7, do_sample=True)
    resposta = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    # Só extrai a parte da resposta (remove o prompt inicial)
    resposta_final = resposta.split("Resposta:")[-1].strip()
    return resposta_final

# ===========================
# 5. Teste interativo!
# ===========================

while True:
    pergunta = input("\n❓ Sua pergunta (ou 'sair'): ")
    if pergunta.lower() == "sair":
        break
    resposta = responder_graphrag(pergunta)
    print("\n🤖 Resposta do GraphRAG:\n", resposta)
# Out:
# ❓ Sua pergunta (ou 'sair'):  Quais são os ativos permitidos pela política de investimento de um FIAGRO?
# 🤖 Resposta do GraphRAG:
#  A política de investimento do FIAGRO define que os ativos permitidos incluem:
#             • Câmbio de açúcar
#             • Feijão
#             • Frutas
#             • Lactose
#             • Milho
#             • Orgao
#             • Peitões de carne
#             • Peixe
#             • Serum
#             • Suínos
#             • Triturados de café
#             • Vegetais
#             • Whisky
#             • Vinho
#
#             Esses ativos são baseados na importância e importância econômica dos produtos e, portanto, são considerados necessários para a satisfação dos objetivos financeiros do fundo.
#
#             A política de investimento também define que os ativos do fundo devem possuir limites específicos, conforme critérios definidos pelo regulamento.
#
# ...
